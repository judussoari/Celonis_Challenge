# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy.interpolate as interp

# %matplotlib inline

# %%
userindex = 8
dayindex = 7
gestureindex = 8
repeatindex = 10

# %% [markdown]
# ## User 1

# %%
df = pd.DataFrame()

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            file = pd.read_csv("uWaveGestureLibrary/U1 ({})/A_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]
            
            #Extract the data to a np array as I am interested in merging the data to 1 column
            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])

            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1) #successively merging the dataframe together

# %% [markdown]
# ## User 2

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            file = pd.read_csv("uWaveGestureLibrary/U2 ({})/C_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]

            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])

            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1)
            #matrix = np.append(matrix,vec,axis=0)

# %% [markdown]
# ## User 3 – At some iteration the array has not enough entries

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            if j == 3 and k == 7 and l == 5: #Skip empy value
                continue
            file = pd.read_csv("uWaveGestureLibrary/U3 ({})/E_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]

            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])

            #Debugging
            #print("Day {}, Gesture {}, Repetition {}".format(j,k,l))

            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1)
            #matrix = np.append(matrix,vec,axis=0)
# Out:
# Day 1, Gesture 1, Repetition 1
# Day 1, Gesture 1, Repetition 2
# Day 1, Gesture 1, Repetition 3
# Day 1, Gesture 1, Repetition 4
# Day 1, Gesture 1, Repetition 5
# Day 1, Gesture 1, Repetition 6
# Day 1, Gesture 1, Repetition 7
# Day 1, Gesture 1, Repetition 8
# Day 1, Gesture 1, Repetition 9
# Day 1, Gesture 1, Repetition 10
# Day 1, Gesture 2, Repetition 1
# Day 1, Gesture 2, Repetition 2
# Day 1, Gesture 2, Repetition 3
# Day 1, Gesture 2, Repetition 4
# Day 1, Gesture 2, Repetition 5
# Day 1, Gesture 2, Repetition 6
# Day 1, Gesture 2, Repetition 7
# Day 1, Gesture 2, Repetition 8
# Day 1, Gesture 2, Repetition 9
# Day 1, Gesture 2, Repetition 10
# Day 1, Gesture 3, Repetition 1
# Day 1, Gesture 3, Repetition 2
# Day 1, Gesture 3, Repetition 3
# Day 1, Gesture 3, Repetition 4
# Day 1, Gesture 3, Repetition 5
# Day 1, Gesture 3, Repetition 6
# Day 1, Gesture 3, Repetition 7
# Day 1, Gesture 3, Repetition 8
# Day 1, Gesture 3, Repetition 9
# Day 1, Gesture 3, Repetition 10
# Day 1, Gesture 4, Repetition 1
# Day 1, Gesture 4, Repetition 2
# Day 1, Gesture 4, Repetition 3
# Day 1, Gesture 4, Repetition 4
# Day 1, Gesture 4, Repetition 5
# Day 1, Gesture 4, Repetition 6
# Day 1, Gesture 4, Repetition 7
# Day 1, Gesture 4, Repetition 8
# Day 1, Gesture 4, Repetition 9
# Day 1, Gesture 4, Repetition 10
# Day 1, Gesture 5, Repetition 1
# Day 1, Gesture 5, Repetition 2
# Day 1, Gesture 5, Repetition 3
# Day 1, Gesture 5, Repetition 4
# Day 1, Gesture 5, Repetition 5
# Day 1, Gesture 5, Repetition 6
# Day 1, Gesture 5, Repetition 7
# Day 1, Gesture 5, Repetition 8
# Day 1, Gesture 5, Repetition 9
# Day 1, Gesture 5, Repetition 10
# Day 1, Gesture 6, Repetition 1
# Day 1, Gesture 6, Repetition 2
# Day 1, Gesture 6, Repetition 3
# Day 1, Gesture 6, Repetition 4
# Day 1, Gesture 6, Repetition 5
# Day 1, Gesture 6, Repetition 6
# Day 1, Gesture 6, Repetition 7
# Day 1, Gesture 6, Repetition 8
# Day 1, Gesture 6, Repetition 9
# Day 1, Gesture 6, Repetition 10
# Day 1, Gesture 7, Repetition 1
# Day 1, Gesture 7, Repetition 2
# Day 1, Gesture 7, Repetition 3
# Day 1, Gesture 7, Repetition 4
# Day 1, Gesture 7, Repetition 5
# Day 1, Gesture 7, Repetition 6
# Day 1, Gesture 7, Repetition 7
# Day 1, Gesture 7, Repetition 8
# Day 1, Gesture 7, Repetition 9
# Day 1, Gesture 7, Repetition 10
# Day 1, Gesture 8, Repetition 1
# Day 1, Gesture 8, Repetition 2
# Day 1, Gesture 8, Repetition 3
# Day 1, Gesture 8, Repetition 4
# Day 1, Gesture 8, Repetition 5
# Day 1, Gesture 8, Repetition 6
# Day 1, Gesture 8, Repetition 7
# Day 1, Gesture 8, Repetition 8
# Day 1, Gesture 8, Repetition 9
# Day 1, Gesture 8, Repetition 10
# Day 2, Gesture 1, Repetition 1
# Day 2, Gesture 1, Repetition 2
# Day 2, Gesture 1, Repetition 3
# Day 2, Gesture 1, Repetition 4
# Day 2, Gesture 1, Repetition 5
# Day 2, Gesture 1, Repetition 6
# Day 2, Gesture 1, Repetition 7
# Day 2, Gesture 1, Repetition 8
# Day 2, Gesture 1, Repetition 9
# Day 2, Gesture 1, Repetition 10
# Day 2, Gesture 2, Repetition 1
# Day 2, Gesture 2, Repetition 2
# Day 2, Gesture 2, Repetition 3
# Day 2, Gesture 2, Repetition 4
# Day 2, Gesture 2, Repetition 5
# Day 2, Gesture 2, Repetition 6
# Day 2, Gesture 2, Repetition 7
# Day 2, Gesture 2, Repetition 8
# Day 2, Gesture 2, Repetition 9
# Day 2, Gesture 2, Repetition 10
# Day 2, Gesture 3, Repetition 1
# Day 2, Gesture 3, Repetition 2
# Day 2, Gesture 3, Repetition 3
# Day 2, Gesture 3, Repetition 4
# Day 2, Gesture 3, Repetition 5
# Day 2, Gesture 3, Repetition 6
# Day 2, Gesture 3, Repetition 7
# Day 2, Gesture 3, Repetition 8
# Day 2, Gesture 3, Repetition 9
# Day 2, Gesture 3, Repetition 10
# Day 2, Gesture 4, Repetition 1
# Day 2, Gesture 4, Repetition 2
# Day 2, Gesture 4, Repetition 3
# Day 2, Gesture 4, Repetition 4
# Day 2, Gesture 4, Repetition 5
# Day 2, Gesture 4, Repetition 6
# Day 2, Gesture 4, Repetition 7
# Day 2, Gesture 4, Repetition 8
# Day 2, Gesture 4, Repetition 9
# Day 2, Gesture 4, Repetition 10
# Day 2, Gesture 5, Repetition 1
# Day 2, Gesture 5, Repetition 2
# Day 2, Gesture 5, Repetition 3
# Day 2, Gesture 5, Repetition 4
# Day 2, Gesture 5, Repetition 5
# Day 2, Gesture 5, Repetition 6
# Day 2, Gesture 5, Repetition 7
# Day 2, Gesture 5, Repetition 8
# Day 2, Gesture 5, Repetition 9
# Day 2, Gesture 5, Repetition 10
# Day 2, Gesture 6, Repetition 1
# Day 2, Gesture 6, Repetition 2
# Day 2, Gesture 6, Repetition 3
# Day 2, Gesture 6, Repetition 4
# Day 2, Gesture 6, Repetition 5
# Day 2, Gesture 6, Repetition 6
# Day 2, Gesture 6, Repetition 7
# Day 2, Gesture 6, Repetition 8
# Day 2, Gesture 6, Repetition 9
# Day 2, Gesture 6, Repetition 10
# Day 2, Gesture 7, Repetition 1
# Day 2, Gesture 7, Repetition 2
# Day 2, Gesture 7, Repetition 3
# Day 2, Gesture 7, Repetition 4
# Day 2, Gesture 7, Repetition 5
# Day 2, Gesture 7, Repetition 6
# Day 2, Gesture 7, Repetition 7
# Day 2, Gesture 7, Repetition 8
# Day 2, Gesture 7, Repetition 9
# Day 2, Gesture 7, Repetition 10
# Day 2, Gesture 8, Repetition 1
# Day 2, Gesture 8, Repetition 2
# Day 2, Gesture 8, Repetition 3
# Day 2, Gesture 8, Repetition 4
# Day 2, Gesture 8, Repetition 5
# Day 2, Gesture 8, Repetition 6
# Day 2, Gesture 8, Repetition 7
# Day 2, Gesture 8, Repetition 8
# Day 2, Gesture 8, Repetition 9
# Day 2, Gesture 8, Repetition 10
# Day 3, Gesture 1, Repetition 1
# Day 3, Gesture 1, Repetition 2
# Day 3, Gesture 1, Repetition 3
# Day 3, Gesture 1, Repetition 4
# Day 3, Gesture 1, Repetition 5
# Day 3, Gesture 1, Repetition 6
# Day 3, Gesture 1, Repetition 7
# Day 3, Gesture 1, Repetition 8
# Day 3, Gesture 1, Repetition 9
# Day 3, Gesture 1, Repetition 10
# Day 3, Gesture 2, Repetition 1
# Day 3, Gesture 2, Repetition 2
# Day 3, Gesture 2, Repetition 3
# Day 3, Gesture 2, Repetition 4
# Day 3, Gesture 2, Repetition 5
# Day 3, Gesture 2, Repetition 6
# Day 3, Gesture 2, Repetition 7
# Day 3, Gesture 2, Repetition 8
# Day 3, Gesture 2, Repetition 9
# Day 3, Gesture 2, Repetition 10
# Day 3, Gesture 3, Repetition 1
# Day 3, Gesture 3, Repetition 2
# Day 3, Gesture 3, Repetition 3
# Day 3, Gesture 3, Repetition 4
# Day 3, Gesture 3, Repetition 5
# Day 3, Gesture 3, Repetition 6
# Day 3, Gesture 3, Repetition 7
# Day 3, Gesture 3, Repetition 8
# Day 3, Gesture 3, Repetition 9
# Day 3, Gesture 3, Repetition 10
# Day 3, Gesture 4, Repetition 1
# Day 3, Gesture 4, Repetition 2
# Day 3, Gesture 4, Repetition 3
# Day 3, Gesture 4, Repetition 4
# Day 3, Gesture 4, Repetition 5
# Day 3, Gesture 4, Repetition 6
# Day 3, Gesture 4, Repetition 7
# Day 3, Gesture 4, Repetition 8
# Day 3, Gesture 4, Repetition 9
# Day 3, Gesture 4, Repetition 10
# Day 3, Gesture 5, Repetition 1
# Day 3, Gesture 5, Repetition 2
# Day 3, Gesture 5, Repetition 3
# Day 3, Gesture 5, Repetition 4
# Day 3, Gesture 5, Repetition 5
# Day 3, Gesture 5, Repetition 6
# Day 3, Gesture 5, Repetition 7
# Day 3, Gesture 5, Repetition 8
# Day 3, Gesture 5, Repetition 9
# Day 3, Gesture 5, Repetition 10
# Day 3, Gesture 6, Repetition 1
# Day 3, Gesture 6, Repetition 2
# Day 3, Gesture 6, Repetition 3
# Day 3, Gesture 6, Repetition 4
# Day 3, Gesture 6, Repetition 5
# Day 3, Gesture 6, Repetition 6
# Day 3, Gesture 6, Repetition 7
# Day 3, Gesture 6, Repetition 8
# Day 3, Gesture 6, Repetition 9
# Day 3, Gesture 6, Repetition 10
# Day 3, Gesture 7, Repetition 1
# Day 3, Gesture 7, Repetition 2
# Day 3, Gesture 7, Repetition 3
# Day 3, Gesture 7, Repetition 4
# Day 3, Gesture 7, Repetition 6
# Day 3, Gesture 7, Repetition 7
# Day 3, Gesture 7, Repetition 8
# Day 3, Gesture 7, Repetition 9
# Day 3, Gesture 7, Repetition 10
# Day 3, Gesture 8, Repetition 1
# Day 3, Gesture 8, Repetition 2
# Day 3, Gesture 8, Repetition 3
# Day 3, Gesture 8, Repetition 4
# Day 3, Gesture 8, Repetition 5
# Day 3, Gesture 8, Repetition 6
# Day 3, Gesture 8, Repetition 7
# Day 3, Gesture 8, Repetition 8
# Day 3, Gesture 8, Repetition 9
# Day 3, Gesture 8, Repetition 10
# Day 4, Gesture 1, Repetition 1
# Day 4, Gesture 1, Repetition 2
# Day 4, Gesture 1, Repetition 3
# Day 4, Gesture 1, Repetition 4
# Day 4, Gesture 1, Repetition 5
# Day 4, Gesture 1, Repetition 6
# Day 4, Gesture 1, Repetition 7
# Day 4, Gesture 1, Repetition 8
# Day 4, Gesture 1, Repetition 9
# Day 4, Gesture 1, Repetition 10
# Day 4, Gesture 2, Repetition 1
# Day 4, Gesture 2, Repetition 2
# Day 4, Gesture 2, Repetition 3
# Day 4, Gesture 2, Repetition 4
# Day 4, Gesture 2, Repetition 5
# Day 4, Gesture 2, Repetition 6
# Day 4, Gesture 2, Repetition 7
# Day 4, Gesture 2, Repetition 8
# Day 4, Gesture 2, Repetition 9
# Day 4, Gesture 2, Repetition 10
# Day 4, Gesture 3, Repetition 1
# Day 4, Gesture 3, Repetition 2
# Day 4, Gesture 3, Repetition 3
# Day 4, Gesture 3, Repetition 4
# Day 4, Gesture 3, Repetition 5
# Day 4, Gesture 3, Repetition 6
# Day 4, Gesture 3, Repetition 7
# Day 4, Gesture 3, Repetition 8
# Day 4, Gesture 3, Repetition 9
# Day 4, Gesture 3, Repetition 10
# Day 4, Gesture 4, Repetition 1
# Day 4, Gesture 4, Repetition 2
# Day 4, Gesture 4, Repetition 3
# Day 4, Gesture 4, Repetition 4
# Day 4, Gesture 4, Repetition 5
# Day 4, Gesture 4, Repetition 6
# Day 4, Gesture 4, Repetition 7
# Day 4, Gesture 4, Repetition 8
# Day 4, Gesture 4, Repetition 9
# Day 4, Gesture 4, Repetition 10
# Day 4, Gesture 5, Repetition 1
# Day 4, Gesture 5, Repetition 2
# Day 4, Gesture 5, Repetition 3
# Day 4, Gesture 5, Repetition 4
# Day 4, Gesture 5, Repetition 5
# Day 4, Gesture 5, Repetition 6
# Day 4, Gesture 5, Repetition 7
# Day 4, Gesture 5, Repetition 8
# Day 4, Gesture 5, Repetition 9
# Day 4, Gesture 5, Repetition 10
# Day 4, Gesture 6, Repetition 1
# Day 4, Gesture 6, Repetition 2
# Day 4, Gesture 6, Repetition 3
# Day 4, Gesture 6, Repetition 4
# Day 4, Gesture 6, Repetition 5
# Day 4, Gesture 6, Repetition 6
# Day 4, Gesture 6, Repetition 7
# Day 4, Gesture 6, Repetition 8
# Day 4, Gesture 6, Repetition 9
# Day 4, Gesture 6, Repetition 10
# Day 4, Gesture 7, Repetition 1
# Day 4, Gesture 7, Repetition 2
# Day 4, Gesture 7, Repetition 3
# Day 4, Gesture 7, Repetition 4
# Day 4, Gesture 7, Repetition 5
# Day 4, Gesture 7, Repetition 6
# Day 4, Gesture 7, Repetition 7
# Day 4, Gesture 7, Repetition 8
# Day 4, Gesture 7, Repetition 9
# Day 4, Gesture 7, Repetition 10
# Day 4, Gesture 8, Repetition 1
# Day 4, Gesture 8, Repetition 2
# Day 4, Gesture 8, Repetition 3
# Day 4, Gesture 8, Repetition 4
# Day 4, Gesture 8, Repetition 5
# Day 4, Gesture 8, Repetition 6
# Day 4, Gesture 8, Repetition 7
# Day 4, Gesture 8, Repetition 8
# Day 4, Gesture 8, Repetition 9
# Day 4, Gesture 8, Repetition 10
# Day 5, Gesture 1, Repetition 1
# Day 5, Gesture 1, Repetition 2
# Day 5, Gesture 1, Repetition 3
# Day 5, Gesture 1, Repetition 4
# Day 5, Gesture 1, Repetition 5
# Day 5, Gesture 1, Repetition 6
# Day 5, Gesture 1, Repetition 7
# Day 5, Gesture 1, Repetition 8
# Day 5, Gesture 1, Repetition 9
# Day 5, Gesture 1, Repetition 10
# Day 5, Gesture 2, Repetition 1
# Day 5, Gesture 2, Repetition 2
# Day 5, Gesture 2, Repetition 3
# Day 5, Gesture 2, Repetition 4
# Day 5, Gesture 2, Repetition 5
# Day 5, Gesture 2, Repetition 6
# Day 5, Gesture 2, Repetition 7
# Day 5, Gesture 2, Repetition 8
# Day 5, Gesture 2, Repetition 9
# Day 5, Gesture 2, Repetition 10
# Day 5, Gesture 3, Repetition 1
# Day 5, Gesture 3, Repetition 2
# Day 5, Gesture 3, Repetition 3
# Day 5, Gesture 3, Repetition 4
# Day 5, Gesture 3, Repetition 5
# Day 5, Gesture 3, Repetition 6
# Day 5, Gesture 3, Repetition 7
# Day 5, Gesture 3, Repetition 8
# Day 5, Gesture 3, Repetition 9
# Day 5, Gesture 3, Repetition 10
# Day 5, Gesture 4, Repetition 1
# Day 5, Gesture 4, Repetition 2
# Day 5, Gesture 4, Repetition 3
# Day 5, Gesture 4, Repetition 4
# Day 5, Gesture 4, Repetition 5
# Day 5, Gesture 4, Repetition 6
# Day 5, Gesture 4, Repetition 7
# Day 5, Gesture 4, Repetition 8
# Day 5, Gesture 4, Repetition 9
# Day 5, Gesture 4, Repetition 10
# Day 5, Gesture 5, Repetition 1
# Day 5, Gesture 5, Repetition 2
# Day 5, Gesture 5, Repetition 3
# Day 5, Gesture 5, Repetition 4
# Day 5, Gesture 5, Repetition 5
# Day 5, Gesture 5, Repetition 6
# Day 5, Gesture 5, Repetition 7
# Day 5, Gesture 5, Repetition 8
# Day 5, Gesture 5, Repetition 9
# Day 5, Gesture 5, Repetition 10
# Day 5, Gesture 6, Repetition 1
# Day 5, Gesture 6, Repetition 2
# Day 5, Gesture 6, Repetition 3
# Day 5, Gesture 6, Repetition 4
# Day 5, Gesture 6, Repetition 5
# Day 5, Gesture 6, Repetition 6
# Day 5, Gesture 6, Repetition 7
# Day 5, Gesture 6, Repetition 8
# Day 5, Gesture 6, Repetition 9
# Day 5, Gesture 6, Repetition 10
# Day 5, Gesture 7, Repetition 1
# Day 5, Gesture 7, Repetition 2
# Day 5, Gesture 7, Repetition 3
# Day 5, Gesture 7, Repetition 4
# Day 5, Gesture 7, Repetition 5
# Day 5, Gesture 7, Repetition 6
# Day 5, Gesture 7, Repetition 7
# Day 5, Gesture 7, Repetition 8
# Day 5, Gesture 7, Repetition 9
# Day 5, Gesture 7, Repetition 10
# Day 5, Gesture 8, Repetition 1
# Day 5, Gesture 8, Repetition 2
# Day 5, Gesture 8, Repetition 3
# Day 5, Gesture 8, Repetition 4
# Day 5, Gesture 8, Repetition 5
# Day 5, Gesture 8, Repetition 6
# Day 5, Gesture 8, Repetition 7
# Day 5, Gesture 8, Repetition 8
# Day 5, Gesture 8, Repetition 9
# Day 5, Gesture 8, Repetition 10
# Day 6, Gesture 1, Repetition 1
# Day 6, Gesture 1, Repetition 2
# Day 6, Gesture 1, Repetition 3
# Day 6, Gesture 1, Repetition 4
# Day 6, Gesture 1, Repetition 5
# Day 6, Gesture 1, Repetition 6
# Day 6, Gesture 1, Repetition 7
# Day 6, Gesture 1, Repetition 8
# Day 6, Gesture 1, Repetition 9
# Day 6, Gesture 1, Repetition 10
# Day 6, Gesture 2, Repetition 1
# Day 6, Gesture 2, Repetition 2
# Day 6, Gesture 2, Repetition 3
# Day 6, Gesture 2, Repetition 4
# Day 6, Gesture 2, Repetition 5
# Day 6, Gesture 2, Repetition 6
# Day 6, Gesture 2, Repetition 7
# Day 6, Gesture 2, Repetition 8
# Day 6, Gesture 2, Repetition 9
# Day 6, Gesture 2, Repetition 10
# Day 6, Gesture 3, Repetition 1
# Day 6, Gesture 3, Repetition 2
# Day 6, Gesture 3, Repetition 3
# Day 6, Gesture 3, Repetition 4
# Day 6, Gesture 3, Repetition 5
# Day 6, Gesture 3, Repetition 6
# Day 6, Gesture 3, Repetition 7
# Day 6, Gesture 3, Repetition 8
# Day 6, Gesture 3, Repetition 9
# Day 6, Gesture 3, Repetition 10
# Day 6, Gesture 4, Repetition 1
# Day 6, Gesture 4, Repetition 2
# Day 6, Gesture 4, Repetition 3
# Day 6, Gesture 4, Repetition 4
# Day 6, Gesture 4, Repetition 5
# Day 6, Gesture 4, Repetition 6
# Day 6, Gesture 4, Repetition 7
# Day 6, Gesture 4, Repetition 8
# Day 6, Gesture 4, Repetition 9
# Day 6, Gesture 4, Repetition 10
# Day 6, Gesture 5, Repetition 1
# Day 6, Gesture 5, Repetition 2
# Day 6, Gesture 5, Repetition 3
# Day 6, Gesture 5, Repetition 4
# Day 6, Gesture 5, Repetition 5
# Day 6, Gesture 5, Repetition 6
# Day 6, Gesture 5, Repetition 7
# Day 6, Gesture 5, Repetition 8
# Day 6, Gesture 5, Repetition 9
# Day 6, Gesture 5, Repetition 10
# Day 6, Gesture 6, Repetition 1
# Day 6, Gesture 6, Repetition 2
# Day 6, Gesture 6, Repetition 3
# Day 6, Gesture 6, Repetition 4
# Day 6, Gesture 6, Repetition 5
# Day 6, Gesture 6, Repetition 6
# Day 6, Gesture 6, Repetition 7
# Day 6, Gesture 6, Repetition 8
# Day 6, Gesture 6, Repetition 9
# Day 6, Gesture 6, Repetition 10
# Day 6, Gesture 7, Repetition 1
# Day 6, Gesture 7, Repetition 2
# Day 6, Gesture 7, Repetition 3
# Day 6, Gesture 7, Repetition 4
# Day 6, Gesture 7, Repetition 5
# Day 6, Gesture 7, Repetition 6
# Day 6, Gesture 7, Repetition 7
# Day 6, Gesture 7, Repetition 8
# Day 6, Gesture 7, Repetition 9
# Day 6, Gesture 7, Repetition 10
# Day 6, Gesture 8, Repetition 1
# Day 6, Gesture 8, Repetition 2
# Day 6, Gesture 8, Repetition 3
# Day 6, Gesture 8, Repetition 4
# Day 6, Gesture 8, Repetition 5
# Day 6, Gesture 8, Repetition 6
# Day 6, Gesture 8, Repetition 7
# Day 6, Gesture 8, Repetition 8
# Day 6, Gesture 8, Repetition 9
# Day 6, Gesture 8, Repetition 10
# Day 7, Gesture 1, Repetition 1
# Day 7, Gesture 1, Repetition 2
# Day 7, Gesture 1, Repetition 3
# Day 7, Gesture 1, Repetition 4
# Day 7, Gesture 1, Repetition 5
# Day 7, Gesture 1, Repetition 6
# Day 7, Gesture 1, Repetition 7
# Day 7, Gesture 1, Repetition 8
# Day 7, Gesture 1, Repetition 9
# Day 7, Gesture 1, Repetition 10
# Day 7, Gesture 2, Repetition 1
# Day 7, Gesture 2, Repetition 2
# Day 7, Gesture 2, Repetition 3
# Day 7, Gesture 2, Repetition 4
# Day 7, Gesture 2, Repetition 5
# Day 7, Gesture 2, Repetition 6
# Day 7, Gesture 2, Repetition 7
# Day 7, Gesture 2, Repetition 8
# Day 7, Gesture 2, Repetition 9
# Day 7, Gesture 2, Repetition 10
# Day 7, Gesture 3, Repetition 1
# Day 7, Gesture 3, Repetition 2
# Day 7, Gesture 3, Repetition 3
# Day 7, Gesture 3, Repetition 4
# Day 7, Gesture 3, Repetition 5
# Day 7, Gesture 3, Repetition 6
# Day 7, Gesture 3, Repetition 7
# Day 7, Gesture 3, Repetition 8
# Day 7, Gesture 3, Repetition 9
# Day 7, Gesture 3, Repetition 10
# Day 7, Gesture 4, Repetition 1
# Day 7, Gesture 4, Repetition 2
# Day 7, Gesture 4, Repetition 3
# Day 7, Gesture 4, Repetition 4
# Day 7, Gesture 4, Repetition 5
# Day 7, Gesture 4, Repetition 6
# Day 7, Gesture 4, Repetition 7
# Day 7, Gesture 4, Repetition 8
# Day 7, Gesture 4, Repetition 9
# Day 7, Gesture 4, Repetition 10
# Day 7, Gesture 5, Repetition 1
# Day 7, Gesture 5, Repetition 2
# Day 7, Gesture 5, Repetition 3
# Day 7, Gesture 5, Repetition 4
# Day 7, Gesture 5, Repetition 5
# Day 7, Gesture 5, Repetition 6
# Day 7, Gesture 5, Repetition 7
# Day 7, Gesture 5, Repetition 8
# Day 7, Gesture 5, Repetition 9
# Day 7, Gesture 5, Repetition 10
# Day 7, Gesture 6, Repetition 1
# Day 7, Gesture 6, Repetition 2
# Day 7, Gesture 6, Repetition 3
# Day 7, Gesture 6, Repetition 4
# Day 7, Gesture 6, Repetition 5
# Day 7, Gesture 6, Repetition 6
# Day 7, Gesture 6, Repetition 7
# Day 7, Gesture 6, Repetition 8
# Day 7, Gesture 6, Repetition 9
# Day 7, Gesture 6, Repetition 10
# Day 7, Gesture 7, Repetition 1
# Day 7, Gesture 7, Repetition 2
# Day 7, Gesture 7, Repetition 3
# Day 7, Gesture 7, Repetition 4
# Day 7, Gesture 7, Repetition 5
# Day 7, Gesture 7, Repetition 6
# Day 7, Gesture 7, Repetition 7
# Day 7, Gesture 7, Repetition 8
# Day 7, Gesture 7, Repetition 9
# Day 7, Gesture 7, Repetition 10
# Day 7, Gesture 8, Repetition 1
# Day 7, Gesture 8, Repetition 2
# Day 7, Gesture 8, Repetition 3
# Day 7, Gesture 8, Repetition 4
# Day 7, Gesture 8, Repetition 5
# Day 7, Gesture 8, Repetition 6
# Day 7, Gesture 8, Repetition 7
# Day 7, Gesture 8, Repetition 8
# Day 7, Gesture 8, Repetition 9
# Day 7, Gesture 8, Repetition 10

# %% [markdown]
# ## User 4

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            file = pd.read_csv("uWaveGestureLibrary/U4 ({})/H_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]

            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])

            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1)
            #matrix = np.append(matrix,vec,axis=0)

# %% [markdown]
# ## User 5

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            file = pd.read_csv("uWaveGestureLibrary/U5 ({})/J_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]

            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])

            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1)
            #matrix = np.append(matrix,vec,axis=0)

# %% [markdown]
# ## User 6

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            file = pd.read_csv("uWaveGestureLibrary/U6 ({})/M_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]

            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])

            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1)
            #matrix = np.append(matrix,vec,axis=0)

# %% [markdown]
# ## User 7 At some iteration the array has not enough entries

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            if j == 6 and k == 1 and l == 5:
                continue
            file = pd.read_csv("uWaveGestureLibrary/U7 ({})/R_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]

            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])
            
            #Debugging:
            #print("Day {}, Gesture {}, Repetition {}".format(j,k,l))
            
            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1)
            #matrix = np.append(matrix,vec,axis=0)
# Out:
# Day 1, Gesture 1, Repetition 1
# Day 1, Gesture 1, Repetition 2
# Day 1, Gesture 1, Repetition 3
# Day 1, Gesture 1, Repetition 4
# Day 1, Gesture 1, Repetition 5
# Day 1, Gesture 1, Repetition 6
# Day 1, Gesture 1, Repetition 7
# Day 1, Gesture 1, Repetition 8
# Day 1, Gesture 1, Repetition 9
# Day 1, Gesture 1, Repetition 10
# Day 1, Gesture 2, Repetition 1
# Day 1, Gesture 2, Repetition 2
# Day 1, Gesture 2, Repetition 3
# Day 1, Gesture 2, Repetition 4
# Day 1, Gesture 2, Repetition 5
# Day 1, Gesture 2, Repetition 6
# Day 1, Gesture 2, Repetition 7
# Day 1, Gesture 2, Repetition 8
# Day 1, Gesture 2, Repetition 9
# Day 1, Gesture 2, Repetition 10
# Day 1, Gesture 3, Repetition 1
# Day 1, Gesture 3, Repetition 2
# Day 1, Gesture 3, Repetition 3
# Day 1, Gesture 3, Repetition 4
# Day 1, Gesture 3, Repetition 5
# Day 1, Gesture 3, Repetition 6
# Day 1, Gesture 3, Repetition 7
# Day 1, Gesture 3, Repetition 8
# Day 1, Gesture 3, Repetition 9
# Day 1, Gesture 3, Repetition 10
# Day 1, Gesture 4, Repetition 1
# Day 1, Gesture 4, Repetition 2
# Day 1, Gesture 4, Repetition 3
# Day 1, Gesture 4, Repetition 4
# Day 1, Gesture 4, Repetition 5
# Day 1, Gesture 4, Repetition 6
# Day 1, Gesture 4, Repetition 7
# Day 1, Gesture 4, Repetition 8
# Day 1, Gesture 4, Repetition 9
# Day 1, Gesture 4, Repetition 10
# Day 1, Gesture 5, Repetition 1
# Day 1, Gesture 5, Repetition 2
# Day 1, Gesture 5, Repetition 3
# Day 1, Gesture 5, Repetition 4
# Day 1, Gesture 5, Repetition 5
# Day 1, Gesture 5, Repetition 6
# Day 1, Gesture 5, Repetition 7
# Day 1, Gesture 5, Repetition 8
# Day 1, Gesture 5, Repetition 9
# Day 1, Gesture 5, Repetition 10
# Day 1, Gesture 6, Repetition 1
# Day 1, Gesture 6, Repetition 2
# Day 1, Gesture 6, Repetition 3
# Day 1, Gesture 6, Repetition 4
# Day 1, Gesture 6, Repetition 5
# Day 1, Gesture 6, Repetition 6
# Day 1, Gesture 6, Repetition 7
# Day 1, Gesture 6, Repetition 8
# Day 1, Gesture 6, Repetition 9
# Day 1, Gesture 6, Repetition 10
# Day 1, Gesture 7, Repetition 1
# Day 1, Gesture 7, Repetition 2
# Day 1, Gesture 7, Repetition 3
# Day 1, Gesture 7, Repetition 4
# Day 1, Gesture 7, Repetition 5
# Day 1, Gesture 7, Repetition 6
# Day 1, Gesture 7, Repetition 7
# Day 1, Gesture 7, Repetition 8
# Day 1, Gesture 7, Repetition 9
# Day 1, Gesture 7, Repetition 10
# Day 1, Gesture 8, Repetition 1
# Day 1, Gesture 8, Repetition 2
# Day 1, Gesture 8, Repetition 3
# Day 1, Gesture 8, Repetition 4
# Day 1, Gesture 8, Repetition 5
# Day 1, Gesture 8, Repetition 6
# Day 1, Gesture 8, Repetition 7
# Day 1, Gesture 8, Repetition 8
# Day 1, Gesture 8, Repetition 9
# Day 1, Gesture 8, Repetition 10
# Day 2, Gesture 1, Repetition 1
# Day 2, Gesture 1, Repetition 2
# Day 2, Gesture 1, Repetition 3
# Day 2, Gesture 1, Repetition 4
# Day 2, Gesture 1, Repetition 5
# Day 2, Gesture 1, Repetition 6
# Day 2, Gesture 1, Repetition 7
# Day 2, Gesture 1, Repetition 8
# Day 2, Gesture 1, Repetition 9
# Day 2, Gesture 1, Repetition 10
# Day 2, Gesture 2, Repetition 1
# Day 2, Gesture 2, Repetition 2
# Day 2, Gesture 2, Repetition 3
# Day 2, Gesture 2, Repetition 4
# Day 2, Gesture 2, Repetition 5
# Day 2, Gesture 2, Repetition 6
# Day 2, Gesture 2, Repetition 7
# Day 2, Gesture 2, Repetition 8
# Day 2, Gesture 2, Repetition 9
# Day 2, Gesture 2, Repetition 10
# Day 2, Gesture 3, Repetition 1
# Day 2, Gesture 3, Repetition 2
# Day 2, Gesture 3, Repetition 3
# Day 2, Gesture 3, Repetition 4
# Day 2, Gesture 3, Repetition 5
# Day 2, Gesture 3, Repetition 6
# Day 2, Gesture 3, Repetition 7
# Day 2, Gesture 3, Repetition 8
# Day 2, Gesture 3, Repetition 9
# Day 2, Gesture 3, Repetition 10
# Day 2, Gesture 4, Repetition 1
# Day 2, Gesture 4, Repetition 2
# Day 2, Gesture 4, Repetition 3
# Day 2, Gesture 4, Repetition 4
# Day 2, Gesture 4, Repetition 5
# Day 2, Gesture 4, Repetition 6
# Day 2, Gesture 4, Repetition 7
# Day 2, Gesture 4, Repetition 8
# Day 2, Gesture 4, Repetition 9
# Day 2, Gesture 4, Repetition 10
# Day 2, Gesture 5, Repetition 1
# Day 2, Gesture 5, Repetition 2
# Day 2, Gesture 5, Repetition 3
# Day 2, Gesture 5, Repetition 4
# Day 2, Gesture 5, Repetition 5
# Day 2, Gesture 5, Repetition 6
# Day 2, Gesture 5, Repetition 7
# Day 2, Gesture 5, Repetition 8
# Day 2, Gesture 5, Repetition 9
# Day 2, Gesture 5, Repetition 10
# Day 2, Gesture 6, Repetition 1
# Day 2, Gesture 6, Repetition 2
# Day 2, Gesture 6, Repetition 3
# Day 2, Gesture 6, Repetition 4
# Day 2, Gesture 6, Repetition 5
# Day 2, Gesture 6, Repetition 6
# Day 2, Gesture 6, Repetition 7
# Day 2, Gesture 6, Repetition 8
# Day 2, Gesture 6, Repetition 9
# Day 2, Gesture 6, Repetition 10
# Day 2, Gesture 7, Repetition 1
# Day 2, Gesture 7, Repetition 2
# Day 2, Gesture 7, Repetition 3
# Day 2, Gesture 7, Repetition 4
# Day 2, Gesture 7, Repetition 5
# Day 2, Gesture 7, Repetition 6
# Day 2, Gesture 7, Repetition 7
# Day 2, Gesture 7, Repetition 8
# Day 2, Gesture 7, Repetition 9
# Day 2, Gesture 7, Repetition 10
# Day 2, Gesture 8, Repetition 1
# Day 2, Gesture 8, Repetition 2
# Day 2, Gesture 8, Repetition 3
# Day 2, Gesture 8, Repetition 4
# Day 2, Gesture 8, Repetition 5
# Day 2, Gesture 8, Repetition 6
# Day 2, Gesture 8, Repetition 7
# Day 2, Gesture 8, Repetition 8
# Day 2, Gesture 8, Repetition 9
# Day 2, Gesture 8, Repetition 10
# Day 3, Gesture 1, Repetition 1
# Day 3, Gesture 1, Repetition 2
# Day 3, Gesture 1, Repetition 3
# Day 3, Gesture 1, Repetition 4
# Day 3, Gesture 1, Repetition 5
# Day 3, Gesture 1, Repetition 6
# Day 3, Gesture 1, Repetition 7
# Day 3, Gesture 1, Repetition 8
# Day 3, Gesture 1, Repetition 9
# Day 3, Gesture 1, Repetition 10
# Day 3, Gesture 2, Repetition 1
# Day 3, Gesture 2, Repetition 2
# Day 3, Gesture 2, Repetition 3
# Day 3, Gesture 2, Repetition 4
# Day 3, Gesture 2, Repetition 5
# Day 3, Gesture 2, Repetition 6
# Day 3, Gesture 2, Repetition 7
# Day 3, Gesture 2, Repetition 8
# Day 3, Gesture 2, Repetition 9
# Day 3, Gesture 2, Repetition 10
# Day 3, Gesture 3, Repetition 1
# Day 3, Gesture 3, Repetition 2
# Day 3, Gesture 3, Repetition 3
# Day 3, Gesture 3, Repetition 4
# Day 3, Gesture 3, Repetition 5
# Day 3, Gesture 3, Repetition 6
# Day 3, Gesture 3, Repetition 7
# Day 3, Gesture 3, Repetition 8
# Day 3, Gesture 3, Repetition 9
# Day 3, Gesture 3, Repetition 10
# Day 3, Gesture 4, Repetition 1
# Day 3, Gesture 4, Repetition 2
# Day 3, Gesture 4, Repetition 3
# Day 3, Gesture 4, Repetition 4
# Day 3, Gesture 4, Repetition 5
# Day 3, Gesture 4, Repetition 6
# Day 3, Gesture 4, Repetition 7
# Day 3, Gesture 4, Repetition 8
# Day 3, Gesture 4, Repetition 9
# Day 3, Gesture 4, Repetition 10
# Day 3, Gesture 5, Repetition 1
# Day 3, Gesture 5, Repetition 2
# Day 3, Gesture 5, Repetition 3
# Day 3, Gesture 5, Repetition 4
# Day 3, Gesture 5, Repetition 5
# Day 3, Gesture 5, Repetition 6
# Day 3, Gesture 5, Repetition 7
# Day 3, Gesture 5, Repetition 8
# Day 3, Gesture 5, Repetition 9
# Day 3, Gesture 5, Repetition 10
# Day 3, Gesture 6, Repetition 1
# Day 3, Gesture 6, Repetition 2
# Day 3, Gesture 6, Repetition 3
# Day 3, Gesture 6, Repetition 4
# Day 3, Gesture 6, Repetition 5
# Day 3, Gesture 6, Repetition 6
# Day 3, Gesture 6, Repetition 7
# Day 3, Gesture 6, Repetition 8
# Day 3, Gesture 6, Repetition 9
# Day 3, Gesture 6, Repetition 10
# Day 3, Gesture 7, Repetition 1
# Day 3, Gesture 7, Repetition 2
# Day 3, Gesture 7, Repetition 3
# Day 3, Gesture 7, Repetition 4
# Day 3, Gesture 7, Repetition 5
# Day 3, Gesture 7, Repetition 6
# Day 3, Gesture 7, Repetition 7
# Day 3, Gesture 7, Repetition 8
# Day 3, Gesture 7, Repetition 9
# Day 3, Gesture 7, Repetition 10
# Day 3, Gesture 8, Repetition 1
# Day 3, Gesture 8, Repetition 2
# Day 3, Gesture 8, Repetition 3
# Day 3, Gesture 8, Repetition 4
# Day 3, Gesture 8, Repetition 5
# Day 3, Gesture 8, Repetition 6
# Day 3, Gesture 8, Repetition 7
# Day 3, Gesture 8, Repetition 8
# Day 3, Gesture 8, Repetition 9
# Day 3, Gesture 8, Repetition 10
# Day 4, Gesture 1, Repetition 1
# Day 4, Gesture 1, Repetition 2
# Day 4, Gesture 1, Repetition 3
# Day 4, Gesture 1, Repetition 4
# Day 4, Gesture 1, Repetition 5
# Day 4, Gesture 1, Repetition 6
# Day 4, Gesture 1, Repetition 7
# Day 4, Gesture 1, Repetition 8
# Day 4, Gesture 1, Repetition 9
# Day 4, Gesture 1, Repetition 10
# Day 4, Gesture 2, Repetition 1
# Day 4, Gesture 2, Repetition 2
# Day 4, Gesture 2, Repetition 3
# Day 4, Gesture 2, Repetition 4
# Day 4, Gesture 2, Repetition 5
# Day 4, Gesture 2, Repetition 6
# Day 4, Gesture 2, Repetition 7
# Day 4, Gesture 2, Repetition 8
# Day 4, Gesture 2, Repetition 9
# Day 4, Gesture 2, Repetition 10
# Day 4, Gesture 3, Repetition 1
# Day 4, Gesture 3, Repetition 2
# Day 4, Gesture 3, Repetition 3
# Day 4, Gesture 3, Repetition 4
# Day 4, Gesture 3, Repetition 5
# Day 4, Gesture 3, Repetition 6
# Day 4, Gesture 3, Repetition 7
# Day 4, Gesture 3, Repetition 8
# Day 4, Gesture 3, Repetition 9
# Day 4, Gesture 3, Repetition 10
# Day 4, Gesture 4, Repetition 1
# Day 4, Gesture 4, Repetition 2
# Day 4, Gesture 4, Repetition 3
# Day 4, Gesture 4, Repetition 4
# Day 4, Gesture 4, Repetition 5
# Day 4, Gesture 4, Repetition 6
# Day 4, Gesture 4, Repetition 7
# Day 4, Gesture 4, Repetition 8
# Day 4, Gesture 4, Repetition 9
# Day 4, Gesture 4, Repetition 10
# Day 4, Gesture 5, Repetition 1
# Day 4, Gesture 5, Repetition 2
# Day 4, Gesture 5, Repetition 3
# Day 4, Gesture 5, Repetition 4
# Day 4, Gesture 5, Repetition 5
# Day 4, Gesture 5, Repetition 6
# Day 4, Gesture 5, Repetition 7
# Day 4, Gesture 5, Repetition 8
# Day 4, Gesture 5, Repetition 9
# Day 4, Gesture 5, Repetition 10
# Day 4, Gesture 6, Repetition 1
# Day 4, Gesture 6, Repetition 2
# Day 4, Gesture 6, Repetition 3
# Day 4, Gesture 6, Repetition 4
# Day 4, Gesture 6, Repetition 5
# Day 4, Gesture 6, Repetition 6
# Day 4, Gesture 6, Repetition 7
# Day 4, Gesture 6, Repetition 8
# Day 4, Gesture 6, Repetition 9
# Day 4, Gesture 6, Repetition 10
# Day 4, Gesture 7, Repetition 1
# Day 4, Gesture 7, Repetition 2
# Day 4, Gesture 7, Repetition 3
# Day 4, Gesture 7, Repetition 4
# Day 4, Gesture 7, Repetition 5
# Day 4, Gesture 7, Repetition 6
# Day 4, Gesture 7, Repetition 7
# Day 4, Gesture 7, Repetition 8
# Day 4, Gesture 7, Repetition 9
# Day 4, Gesture 7, Repetition 10
# Day 4, Gesture 8, Repetition 1
# Day 4, Gesture 8, Repetition 2
# Day 4, Gesture 8, Repetition 3
# Day 4, Gesture 8, Repetition 4
# Day 4, Gesture 8, Repetition 5
# Day 4, Gesture 8, Repetition 6
# Day 4, Gesture 8, Repetition 7
# Day 4, Gesture 8, Repetition 8
# Day 4, Gesture 8, Repetition 9
# Day 4, Gesture 8, Repetition 10
# Day 5, Gesture 1, Repetition 1
# Day 5, Gesture 1, Repetition 2
# Day 5, Gesture 1, Repetition 3
# Day 5, Gesture 1, Repetition 4
# Day 5, Gesture 1, Repetition 5
# Day 5, Gesture 1, Repetition 6
# Day 5, Gesture 1, Repetition 7
# Day 5, Gesture 1, Repetition 8
# Day 5, Gesture 1, Repetition 9
# Day 5, Gesture 1, Repetition 10
# Day 5, Gesture 2, Repetition 1
# Day 5, Gesture 2, Repetition 2
# Day 5, Gesture 2, Repetition 3
# Day 5, Gesture 2, Repetition 4
# Day 5, Gesture 2, Repetition 5
# Day 5, Gesture 2, Repetition 6
# Day 5, Gesture 2, Repetition 7
# Day 5, Gesture 2, Repetition 8
# Day 5, Gesture 2, Repetition 9
# Day 5, Gesture 2, Repetition 10
# Day 5, Gesture 3, Repetition 1
# Day 5, Gesture 3, Repetition 2
# Day 5, Gesture 3, Repetition 3
# Day 5, Gesture 3, Repetition 4
# Day 5, Gesture 3, Repetition 5
# Day 5, Gesture 3, Repetition 6
# Day 5, Gesture 3, Repetition 7
# Day 5, Gesture 3, Repetition 8
# Day 5, Gesture 3, Repetition 9
# Day 5, Gesture 3, Repetition 10
# Day 5, Gesture 4, Repetition 1
# Day 5, Gesture 4, Repetition 2
# Day 5, Gesture 4, Repetition 3
# Day 5, Gesture 4, Repetition 4
# Day 5, Gesture 4, Repetition 5
# Day 5, Gesture 4, Repetition 6
# Day 5, Gesture 4, Repetition 7
# Day 5, Gesture 4, Repetition 8
# Day 5, Gesture 4, Repetition 9
# Day 5, Gesture 4, Repetition 10
# Day 5, Gesture 5, Repetition 1
# Day 5, Gesture 5, Repetition 2
# Day 5, Gesture 5, Repetition 3
# Day 5, Gesture 5, Repetition 4
# Day 5, Gesture 5, Repetition 5
# Day 5, Gesture 5, Repetition 6
# Day 5, Gesture 5, Repetition 7
# Day 5, Gesture 5, Repetition 8
# Day 5, Gesture 5, Repetition 9
# Day 5, Gesture 5, Repetition 10
# Day 5, Gesture 6, Repetition 1
# Day 5, Gesture 6, Repetition 2
# Day 5, Gesture 6, Repetition 3
# Day 5, Gesture 6, Repetition 4
# Day 5, Gesture 6, Repetition 5
# Day 5, Gesture 6, Repetition 6
# Day 5, Gesture 6, Repetition 7
# Day 5, Gesture 6, Repetition 8
# Day 5, Gesture 6, Repetition 9
# Day 5, Gesture 6, Repetition 10
# Day 5, Gesture 7, Repetition 1
# Day 5, Gesture 7, Repetition 2
# Day 5, Gesture 7, Repetition 3
# Day 5, Gesture 7, Repetition 4
# Day 5, Gesture 7, Repetition 5
# Day 5, Gesture 7, Repetition 6
# Day 5, Gesture 7, Repetition 7
# Day 5, Gesture 7, Repetition 8
# Day 5, Gesture 7, Repetition 9
# Day 5, Gesture 7, Repetition 10
# Day 5, Gesture 8, Repetition 1
# Day 5, Gesture 8, Repetition 2
# Day 5, Gesture 8, Repetition 3
# Day 5, Gesture 8, Repetition 4
# Day 5, Gesture 8, Repetition 5
# Day 5, Gesture 8, Repetition 6
# Day 5, Gesture 8, Repetition 7
# Day 5, Gesture 8, Repetition 8
# Day 5, Gesture 8, Repetition 9
# Day 5, Gesture 8, Repetition 10
# Day 6, Gesture 1, Repetition 1
# Day 6, Gesture 1, Repetition 2
# Day 6, Gesture 1, Repetition 3
# Day 6, Gesture 1, Repetition 4
# Day 6, Gesture 1, Repetition 6
# Day 6, Gesture 1, Repetition 7
# Day 6, Gesture 1, Repetition 8
# Day 6, Gesture 1, Repetition 9
# Day 6, Gesture 1, Repetition 10
# Day 6, Gesture 2, Repetition 1
# Day 6, Gesture 2, Repetition 2
# Day 6, Gesture 2, Repetition 3
# Day 6, Gesture 2, Repetition 4
# Day 6, Gesture 2, Repetition 5
# Day 6, Gesture 2, Repetition 6
# Day 6, Gesture 2, Repetition 7
# Day 6, Gesture 2, Repetition 8
# Day 6, Gesture 2, Repetition 9
# Day 6, Gesture 2, Repetition 10
# Day 6, Gesture 3, Repetition 1
# Day 6, Gesture 3, Repetition 2
# Day 6, Gesture 3, Repetition 3
# Day 6, Gesture 3, Repetition 4
# Day 6, Gesture 3, Repetition 5
# Day 6, Gesture 3, Repetition 6
# Day 6, Gesture 3, Repetition 7
# Day 6, Gesture 3, Repetition 8
# Day 6, Gesture 3, Repetition 9
# Day 6, Gesture 3, Repetition 10
# Day 6, Gesture 4, Repetition 1
# Day 6, Gesture 4, Repetition 2
# Day 6, Gesture 4, Repetition 3
# Day 6, Gesture 4, Repetition 4
# Day 6, Gesture 4, Repetition 5
# Day 6, Gesture 4, Repetition 6
# Day 6, Gesture 4, Repetition 7
# Day 6, Gesture 4, Repetition 8
# Day 6, Gesture 4, Repetition 9
# Day 6, Gesture 4, Repetition 10
# Day 6, Gesture 5, Repetition 1
# Day 6, Gesture 5, Repetition 2
# Day 6, Gesture 5, Repetition 3
# Day 6, Gesture 5, Repetition 4
# Day 6, Gesture 5, Repetition 5
# Day 6, Gesture 5, Repetition 6
# Day 6, Gesture 5, Repetition 7
# Day 6, Gesture 5, Repetition 8
# Day 6, Gesture 5, Repetition 9
# Day 6, Gesture 5, Repetition 10
# Day 6, Gesture 6, Repetition 1
# Day 6, Gesture 6, Repetition 2
# Day 6, Gesture 6, Repetition 3
# Day 6, Gesture 6, Repetition 4
# Day 6, Gesture 6, Repetition 5
# Day 6, Gesture 6, Repetition 6
# Day 6, Gesture 6, Repetition 7
# Day 6, Gesture 6, Repetition 8
# Day 6, Gesture 6, Repetition 9
# Day 6, Gesture 6, Repetition 10
# Day 6, Gesture 7, Repetition 1
# Day 6, Gesture 7, Repetition 2
# Day 6, Gesture 7, Repetition 3
# Day 6, Gesture 7, Repetition 4
# Day 6, Gesture 7, Repetition 5
# Day 6, Gesture 7, Repetition 6
# Day 6, Gesture 7, Repetition 7
# Day 6, Gesture 7, Repetition 8
# Day 6, Gesture 7, Repetition 9
# Day 6, Gesture 7, Repetition 10
# Day 6, Gesture 8, Repetition 1
# Day 6, Gesture 8, Repetition 2
# Day 6, Gesture 8, Repetition 3
# Day 6, Gesture 8, Repetition 4
# Day 6, Gesture 8, Repetition 5
# Day 6, Gesture 8, Repetition 6
# Day 6, Gesture 8, Repetition 7
# Day 6, Gesture 8, Repetition 8
# Day 6, Gesture 8, Repetition 9
# Day 6, Gesture 8, Repetition 10
# Day 7, Gesture 1, Repetition 1
# Day 7, Gesture 1, Repetition 2
# Day 7, Gesture 1, Repetition 3
# Day 7, Gesture 1, Repetition 4
# Day 7, Gesture 1, Repetition 5
# Day 7, Gesture 1, Repetition 6
# Day 7, Gesture 1, Repetition 7
# Day 7, Gesture 1, Repetition 8
# Day 7, Gesture 1, Repetition 9
# Day 7, Gesture 1, Repetition 10
# Day 7, Gesture 2, Repetition 1
# Day 7, Gesture 2, Repetition 2
# Day 7, Gesture 2, Repetition 3
# Day 7, Gesture 2, Repetition 4
# Day 7, Gesture 2, Repetition 5
# Day 7, Gesture 2, Repetition 6
# Day 7, Gesture 2, Repetition 7
# Day 7, Gesture 2, Repetition 8
# Day 7, Gesture 2, Repetition 9
# Day 7, Gesture 2, Repetition 10
# Day 7, Gesture 3, Repetition 1
# Day 7, Gesture 3, Repetition 2
# Day 7, Gesture 3, Repetition 3
# Day 7, Gesture 3, Repetition 4
# Day 7, Gesture 3, Repetition 5
# Day 7, Gesture 3, Repetition 6
# Day 7, Gesture 3, Repetition 7
# Day 7, Gesture 3, Repetition 8
# Day 7, Gesture 3, Repetition 9
# Day 7, Gesture 3, Repetition 10
# Day 7, Gesture 4, Repetition 1
# Day 7, Gesture 4, Repetition 2
# Day 7, Gesture 4, Repetition 3
# Day 7, Gesture 4, Repetition 4
# Day 7, Gesture 4, Repetition 5
# Day 7, Gesture 4, Repetition 6
# Day 7, Gesture 4, Repetition 7
# Day 7, Gesture 4, Repetition 8
# Day 7, Gesture 4, Repetition 9
# Day 7, Gesture 4, Repetition 10
# Day 7, Gesture 5, Repetition 1
# Day 7, Gesture 5, Repetition 2
# Day 7, Gesture 5, Repetition 3
# Day 7, Gesture 5, Repetition 4
# Day 7, Gesture 5, Repetition 5
# Day 7, Gesture 5, Repetition 6
# Day 7, Gesture 5, Repetition 7
# Day 7, Gesture 5, Repetition 8
# Day 7, Gesture 5, Repetition 9
# Day 7, Gesture 5, Repetition 10
# Day 7, Gesture 6, Repetition 1
# Day 7, Gesture 6, Repetition 2
# Day 7, Gesture 6, Repetition 3
# Day 7, Gesture 6, Repetition 4
# Day 7, Gesture 6, Repetition 5
# Day 7, Gesture 6, Repetition 6
# Day 7, Gesture 6, Repetition 7
# Day 7, Gesture 6, Repetition 8
# Day 7, Gesture 6, Repetition 9
# Day 7, Gesture 6, Repetition 10
# Day 7, Gesture 7, Repetition 1
# Day 7, Gesture 7, Repetition 2
# Day 7, Gesture 7, Repetition 3
# Day 7, Gesture 7, Repetition 4
# Day 7, Gesture 7, Repetition 5
# Day 7, Gesture 7, Repetition 6
# Day 7, Gesture 7, Repetition 7
# Day 7, Gesture 7, Repetition 8
# Day 7, Gesture 7, Repetition 9
# Day 7, Gesture 7, Repetition 10
# Day 7, Gesture 8, Repetition 1
# Day 7, Gesture 8, Repetition 2
# Day 7, Gesture 8, Repetition 3
# Day 7, Gesture 8, Repetition 4
# Day 7, Gesture 8, Repetition 5
# Day 7, Gesture 8, Repetition 6
# Day 7, Gesture 8, Repetition 7
# Day 7, Gesture 8, Repetition 8
# Day 7, Gesture 8, Repetition 9
# Day 7, Gesture 8, Repetition 10

# %% [markdown]
# ## User 8

# %%
#iteration over every .txt file for User 1
for j in range(1,dayindex+1):
    for k in range(1,gestureindex+1):
        for l in range(1,repeatindex+1):
            file = pd.read_csv("uWaveGestureLibrary/U8 ({})/Z_Template_Acceleration{}-{}.txt".format(j,k,l),
                             header=None,sep=" ")
            #define the columns
            file.columns = ["X Acceleration","Y Acceleration","Z Acceleration"]

            vec1 = np.array([file["X Acceleration"],file["Y Acceleration"],file["Z Acceleration"]])

            vec21 = vec1[0] #X Acceleration
            vec22 = vec1[1] #Y Acceleration
            vec23 = vec1[2] #Z Acceleration

            vec31 = interp.interp1d(np.arange(vec21.size),vec21) #Interpolation of the respective values
            vec32 = interp.interp1d(np.arange(vec22.size),vec22)
            vec33 = interp.interp1d(np.arange(vec23.size),vec23)

            vec41 = vec31(np.linspace(0,vec21.size-1,100)) #To finally have a unified size for every time series
            vec42 = vec32(np.linspace(0,vec22.size-1,100))
            vec43 = vec33(np.linspace(0,vec23.size-1,100))

            vec = np.array([vec41,vec42,vec43]).reshape(300,) #1-row vector containing X,Y and Z
            vec = np.append(vec,k)
            ser = pd.Series(vec)
            df = pd.concat([df,ser],axis=1)
            #matrix = np.append(matrix,vec,axis=0)

# %% [markdown]
# ## Transpose the Matrix
# ### Label is visible and easily extractable after transposing the dataframe

# %%
df_transpo = df.transpose()

# %%
df_transpo[300]
df_transpo=df_transpo.rename(columns = {300:'Label'}) #rename the last column as this is my label

# %%
df_transpo

# %% [markdown]
# # Exploration

# %%
df_transpo.info()
#every column contains numerical data only.

# %%
#No Zero values in the df
df_transpo.isnull().sum()

# %%
df_transpo.describe()

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="Label",data=df_transpo)

#As expected, the amount of labels is equally distributed

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_transpo.corr(), cmap="coolwarm")
plt.title("df_transpo.corr()")

# Features, which are not exactly grabable anymore, show some nice correlation with the label and among eath other

# %%
df_transpo.corr()['Label'].sort_values().plot(kind='bar')
#some nice correlations are visible

# %% [markdown]
# ## Multinomial Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression

# %%
df_transpo.head()

# %%
#Task: Given a time series, perform gesture detection
X = df_transpo.drop("Label",axis=1)
y = df_transpo["Label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
#Multinomial, because I am dealing with 8 classes
#Solver: default one – Others possible
#C: Regularization parameter. The closer to 0, the harder penalization
model = LogisticRegression(multi_class='multinomial', solver='lbfgs',penalty="l2",C=0.001)

# %%
model.fit(X_train,y_train)

# %%
pred = model.predict(X_test)

# %%
pred[0:20]

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,pred))

# %%
#Overall very good results already, after some hyperparameter tuning
#Further Options: Hyperparameter tuning, new ML model (SVM,ANN), Data Normalization, Cross-validation, 
confusion_matrix(y_test,pred)

# %% [markdown]
# ## Save the model to deploy it to GCP

# %%
import pickle
with open('model.pkl', 'wb') as files:
    pickle.dump(model, files)

# %% [markdown]
# ## Get online predictions from the model deployed to GCP

# %%
def endpoint_predict_sample(
    project: str, location: str, instances: list, endpoint: str
):
    aiplatform.init(project=project, location=location)

    endpoint = aiplatform.Endpoint(endpoint)

    prediction = endpoint.predict(instances=instances)
    print(prediction)
    return prediction

endpoint_predict_sample("julioare-project1","us-central1",df_transpo.iloc[5],"endpoint_pickle")

# %% [markdown]
# ## Save the Dataset

# %%
df_transpo.to_csv("gesture_dataset.csv")
